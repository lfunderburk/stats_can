# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %% [markdown]
# ![alt text](https://github.com/callysto/callysto-sample-notebooks/blob/master/notebooks/images/Callysto_Notebook-Banner_Top_06.06.18.jpg?raw=true)

# %% [markdown]
# <h1 align='center'>Exploring Python api for Statistics Canada New Data Model (NDM)</h1>
#
# <h4 align='center'>Laura Gutierrez Funderburk $\mid$ November 1 2018</h4>
#
# <h2 align='center'>Abstract</h2>
#
# In this notebook we explore functionality of the Python API for Statistics Canada developed by Ian Preston
# https://anaconda.org/ian.e.preston/stats_can
#
# <h2 align='center'>About Stats Canada</h2>
#
# Statistics Canada is the national statistical office. The agency ensures Canadians have the key information on Canada's economy, society and environment that they require to function effectively as citizens and decision makers.
#
#
# ![Stats Canada Main Page](./StatsCanada.png)
#
# URL: https://www.statcan.gc.ca/eng/start
#
# <h2 align='center'>About the Stats Can Python Library</h2>
#
# The Stats_Can library retrieves up-to-date data from the Statistics Canada API, making it a powerful tool to explore statistics on Canada.
#
# <h2 align='center'>Exploring the Stats Can Python Library using Jupyter Notebooks</h2>
#
# We can explore the database from two different angles:
#
# <h4>Retrieve the latest lists series:</h4> This option will return a comprehensive list of all tables pointing to different datasets.
#
# <h4>Retrieve a particular study:</h4> This option will give access to metadata and data pertaining a particular study.

# %% [markdown]
# <h2 align='center'>Retrieve latest list series</h2>
#
# In this section we will explore the last 100 datasets released. We will use the Python Library Stats Can to get that data, without navigating the entire Stats Canada Database.

# %%
### import stats_can
import datetime as dt
import pandas as pd
import matplotlib as plt
import stats_can
import json
from pprint import pprint

# %%
# %run -i ./stats_can/scwds.py

# %%
# %run -i ./stats_can/sc.py

# %%
changed_series = stats_can.get_changed_series_list()
changed_series_df = pd.DataFrame.from_dict(changed_series)
short_series_list = changed_series_df.head(n=25)

# %%
short_series_list
# Out:
#               coordinate  productId       releaseTime  responseStatusCode  \
# 0   1.14.0.0.0.0.0.0.0.0   33100036  2018-11-01T08:30                   0
# 1   1.24.0.0.0.0.0.0.0.0   33100036  2018-11-01T08:30                   0
# 2   1.22.0.0.0.0.0.0.0.0   10100139  2018-11-01T08:30                   0
# 3   1.24.0.0.0.0.0.0.0.0   10100139  2018-11-01T08:30                   0
# 4   1.13.0.0.0.0.0.0.0.0   10100139  2018-11-01T08:30                   0
# 5   1.53.0.0.0.0.0.0.0.0   10100144  2018-11-01T08:30                   0
# 6   1.55.0.0.0.0.0.0.0.0   10100144  2018-11-01T08:30                   0
# 7   1.24.0.0.0.0.0.0.0.0   10100107  2018-11-01T08:30                   0
# 8   1.15.0.0.0.0.0.0.0.0   10100107  2018-11-01T08:30                   0
# 9   1.14.0.0.0.0.0.0.0.0   10100125  2018-11-01T08:30                   0
# 10  1.15.0.0.0.0.0.0.0.0   10100125  2018-11-01T08:30                   0
# 11   6.4.0.0.0.0.0.0.0.0   34100210  2018-11-01T08:30                   0
# 12   8.3.0.0.0.0.0.0.0.0   34100210  2018-11-01T08:30                   0
# 13   7.9.0.0.0.0.0.0.0.0   34100210  2018-11-01T08:30                   0
# 14   8.5.0.0.0.0.0.0.0.0   34100210  2018-11-01T08:30                   0
# 15   9.1.0.0.0.0.0.0.0.0   34100210  2018-11-01T08:30                   0
# 16  11.8.0.0.0.0.0.0.0.0   34100210  2018-11-01T08:30                   0
# 17  13.5.0.0.0.0.0.0.0.0   34100210  2018-11-01T08:30                   0
# 18  14.9.0.0.0.0.0.0.0.0   34100210  2018-11-01T08:30                   0
# 19   2.5.0.0.0.0.0.0.0.0   34100210  2018-11-01T08:30                   0
# 20   3.6.0.0.0.0.0.0.0.0   34100210  2018-11-01T08:30                   0
# 21   4.7.4.0.0.0.0.0.0.0   34100211  2018-11-01T08:30                   0
# 22   4.4.3.0.0.0.0.0.0.0   34100211  2018-11-01T08:30                   0
# 23   5.3.3.0.0.0.0.0.0.0   34100211  2018-11-01T08:30                   0
# 24   1.5.4.0.0.0.0.0.0.0   34100211  2018-11-01T08:30                   0
#
#       vectorId
# 0    111666237
# 1    111666247
# 2        39061
# 3        39063
# 4        39051
# 5     80691306
# 6     80691308
# 7        36646
# 8        36637
# 9     19457778
# 10    19457779
# 11  1014021519
# 12  1014021507
# 13  1014021590
# 14  1014021535
# 15  1014021480
# 16  1014021580
# 17  1014021540
# 18  1014021597
# 19  1014021529
# 20  1014021544
# 21  1014022315
# 22  1014021965
# 23  1014021854
# 24  1014022088

# %% [markdown]
# <h2 align='center'>Retrieve a particular dataset</h2>
#
#
# We can use the values under the productId column to retrieve what is known as "cube" or "table" metadata. Metadata act as pointers to the actual data, and provide sufficient information to understand the type of study, without diving into the details. This is useful, as some of the data within Stats Canada is large.
#
# Metadata can be called from the Statistics Canada Database - information is obtained in the form of a JSON file which can be formatted for processing.
#
# Let us pick the first entry, with productId 33100036 and obtain metadata.

# %%
# Download first entry, at the time this notebook was written, the table selected had a ProductId 33100036 
download_tables("33100036")
with open('33100036.json') as f:
    data = json.load(f)

# %%
keys_names = [item for item in data.keys()]
for i in range(len(keys_names)-3):
    print(str(keys_names[i]) + ":\t"+ str(data[keys_names[i]]))
# Out:
# responseStatusCode:	0
# productId:	33100036
# cansimId:	176-0080
# cubeTitleEn:	Daily average foreign exchange rates in Canadian dollars, Bank of Canada
# cubeTitleFr:	Taux de change moyens quotidiens en dollars canadiens, Banque du Canada
# cubeStartDate:	1981-05-04
# cubeEndDate:	2018-10-30
# nbSeriesCube:	27
# nbDatapointsCube:	30941
# archiveStatusCode:	2
# archiveStatusEn:	CURRENT - a cube available to the public and that is current
# archiveStatusFr:	ACTIF - un cube qui est disponible au public et qui est toujours mise a jour
# subjectCode:	['1004', '330304']
# surveyCode:	['7502']

# %% [markdown]
# We then see that the above is a study that contains data on "Daily average foreign exchange rates in Canadian dollars, Bank of Canada" ("Taux de change moyens quotidiens en dollars canadiens, Banque du Canada") which was conducted between January 1, 1967 and September 1, 2018.
#
# We can download the data and explore it using Python's libraries Matplotlib and Pandas Dataframes.

# %%
pd.read_csv("./exchange.csv")
# Out:
#                             Unnamed: 0            Canada        Unnamed: 2  \
# 0                     Type of currency  October 26, 2018  October 27, 2018
# 1     Australian dollar, daily average            0.9274                 0
# 2        Brazilian real, daily average             0.357                 0
# 3      Chinese renminbi, daily average            0.1887                 0
# 4         European euro, daily average            1.4921                 0
# 5      Hong Kong dollar, daily average            0.1672                 0
# 6          Indian rupee, daily average           0.01784                 0
# 7     Indonesian rupiah, daily average          0.000086                 0
# 8          Japanese yen, daily average           0.01172                 0
# 9     Malaysian ringgit, daily average             0.314                 0
# 10         Mexican peso, daily average           0.06734                 0
# 11   New Zealand dollar, daily average            0.8531                 0
# 12      Norwegian krone, daily average            0.1569                 0
# 13     Peruvian new sol, daily average            0.3918                 0
# 14        Russian ruble, daily average           0.01993                 0
# 15          Saudi riyal, daily average            0.3495                 0
# 16     Singapore dollar, daily average            0.9489                 0
# 17   South African rand, daily average           0.08954                 0
# 18     South Korean won, daily average          0.001148                 0
# 19        Swedish krona, daily average            0.1435                 0
# 20          Swiss franc, daily average            1.3122                 0
# 21     Taiwanese dollar, daily average           0.04229                 0
# 22            Thai baht, daily average           0.03961                 0
# 23         Turkish lira, daily average            0.2339                 0
# 24  U.K. pound sterling, daily average            1.6806                 0
# 25          U.S. dollar, daily average            1.3108                 0
# 26      Vietnamese dong, daily average          0.000056                 0
#
#           Unnamed: 3        Unnamed: 4        Unnamed: 5
# 0   October 28, 2018  October 29, 2018  October 30, 2018
# 1                  0            0.9279            0.9331
# 2                  0            0.3582            0.3541
# 3                  0            0.1885            0.1885
# 4                  0            1.4935            1.4917
# 5                  0            0.1673            0.1674
# 6                  0           0.01787           0.01784
# 7                  0          0.000086          0.000086
# 8                  0           0.01167           0.01164
# 9                  0            0.3138             0.314
# 10                 0           0.06616            0.0656
# 11                 0            0.8568            0.8613
# 12                 0            0.1567            0.1563
# 13                 0            0.3914             0.391
# 14                 0              0.02              0.02
# 15                 0            0.3497            0.3501
# 16                 0            0.9487            0.9488
# 17                 0           0.09009           0.08981
# 18                 0           0.00115          0.001153
# 19                 0            0.1436            0.1433
# 20                 0            1.3108            1.3085
# 21                 0           0.04236           0.04243
# 22                 0           0.03948           0.03946
# 23                 0            0.2364            0.2392
# 24                 0            1.6805             1.672
# 25                 0            1.3119            1.3133
# 26                 0          0.000056          0.000056

# %% [markdown]
# ![alt text](https://github.com/callysto/callysto-sample-notebooks/blob/master/notebooks/images/Callysto_Notebook-Banners_Bottom_06.06.18.jpg?raw=true)
